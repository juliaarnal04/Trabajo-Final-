# %% [markdown]
# # PRACTICA 2  JÚLIA ARNAL Y JORGE ESCALERA
#
# ### ¡Con todo lo aprendido con Python, vamos a resolver unos ejercicios de Bioinformática!
#
# #### 1.- Concatena las cadenas ATGCC y TCCG

# %%
cadena1 = "ATGCC"
cadena2 = "TCCG"

# %%
cadena1 = "ATGCC"
cadena2 = "TCCG"
resultado = cadena1 + cadena2
print("Concatenación:", resultado)
# Out:
# Concatenación: ATGCCTCCG

# %% [markdown]
# #### 2.- ¿Cuál es la longitud de ATGCGAGT?

# %%
dna="ATGCGAGT"

# %%
dna = "ATGCGAGT"
longitud = len(dna)
print(longitud)
# Out:
# 8

# %% [markdown]
# #### 3.- Con la cadena mgXDyTw, ponla en mayúsculas, luego en minúsculas. Extrae su longitud y divide la cadena por la letra "g"

# %%
cadena="mgXDyTw"

# %%
cadena = "mgXDyTw"

print(cadena.upper())
print(cadena.lower())
print(len(cadena))
print(cadena.split("g"))
# Out:
# MGXDYTW
# mgxdytw
# 7
# ['m', 'XDyTw']

# %% [markdown]
# #### 4.- Con la secuencia de aminoácidos vlspadktnv, reemplaza la valina con la tirosina. Pista: usa replace()

# %%
aa = "vlspadktnv"

# %%
aa = "vlspadktnv"
aa_nueva = aa.replace("v", "y")
print(aa_nueva)
# Out:
# ylspadktny

# %% [markdown]
# #### 5.- Cuenta las valinas de la secuencia original anterior.

# %%
import builtins
aa = "vlspadktnv"
numero_valinas = aa.count("v")
builtins.print(numero_valinas)
# Out:
# 2

# %% [markdown]
# #### 6.- Con el diccionario siguiente imprime el valor de BisI y saca el valor de EcoRI con pop(). ¿Qué pasa con el diccionario?

# %%
enzR = {
    'EcoRI':r'GAATTC',
    'AvaII':r'GG(A|T)CC',
    'BisI':r'GC[ATGC]GC'
}

# %%
import builtins
print = builtins.print
enzR = {
    'EcoRI': r'GAATTC',
    'AvaII': r'GG(A|T)CC',
    'BisI': r'GC[ATGC]GC'
}
print("Valor de BisI:", enzR['BisI'])
valor_ecori = enzR.pop('EcoRI')
print("Valor de EcoRI (usando pop):", valor_ecori)
print("Diccionario tras pop():", enzR)
# Out:
# Valor de BisI: GC[ATGC]GC
# Valor de EcoRI (usando pop): GAATTC
# Diccionario tras pop(): {'AvaII': 'GG(A|T)CC', 'BisI': 'GC[ATGC]GC'}

# %% [markdown]
# #### 7.- Con la secuencia y la lista siguiente, escribe un algoritmo que cuente el número de veces que aparece un elemento de la lista en la secuencia. Pista: hacer un diccionario para almacenar los resultados puede ser buena idea

# %%
dna = "AATGATGAACGAC" 
dinucleotides = ['AA','AT','AG','AC', 
                 'TA','TT','TG','TC', 
                 'GA','GT','GG','GC', 
                 'CA','CT','CG','CT']

# %%
dna = "AATGATGAACGAC"
dinucleotides = ['AA','AT','AG','AC', 
                 'TA','TT','TG','TC', 
                 'GA','GT','GG','GC', 
                 'CA','CT','CG','CT']
conteo = {}
for d in dinucleotides:
    conteo[d] = dna.count(d)
print(conteo)
# Out:
# {'AA': 2, 'AT': 2, 'AG': 0, 'AC': 2, 'TA': 0, 'TT': 0, 'TG': 2, 'TC': 0, 'GA': 3, 'GT': 0, 'GG': 0, 'GC': 0, 'CA': 0, 'CT': 0, 'CG': 1}

# %% [markdown]
# ##### ¿Cuántos counts tiene TC?

# %%
print("TC aparece", conteo['TC'], "veces")
# Out:
# TC aparece 0 veces

# %% [markdown]
# ##### ¿Puedes imprimir los dinuleótidos que tengan counts igual a 2?

# %%
for d, c in conteo.items():
 if c == 2:
    print(d, "aparece 2 veces")
# Out:
# AA aparece 2 veces
# AT aparece 2 veces
# AC aparece 2 veces
# TG aparece 2 veces
